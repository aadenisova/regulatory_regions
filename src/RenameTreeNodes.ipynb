# %%
from ete3 import Tree

PATH = "/lustre/fs5/vgl/store/adenisova/Inno/upstreams/"
tree_from_file = open(f"{PATH}/cooney_tree.tree", "r").read()
tree = Tree(tree_from_file)

# %%
cactus_tree_from_file = open(f"{PATH}/cactus.tree", "r").read()
cactus_tree = Tree(cactus_tree_from_file, format=1)

# %%
print(cactus_tree)
# Out:
#    /-GCA_009819545.1_rLacAgi1.alt
#   |
#   |   /-GCF_015237465.2_rCheMyd1.pri.v2
#   |  |
# --|  |   /-GCA_016128335.1_ZJU1.0
#   |  |  |
#   |  |  |         /-GCF_009769625.2_bCygOlo1.pri.v2
#   |  |  |      /-|
#    \-|  |     |  |   /-GCF_015476345.1_ZJU1.0
#      |  |     |   \-|
#      |  |   /-|      \-GCF_009819795.1_bAytFul2.pri
#      |  |  |  |
#      |  |  |  |   /-GCA_905368555.1_MGAL_WU_HG_1.0
#      |  |  |   \-|
#      |  |  |     |   /-GCF_000002315.5_GalGal6
#       \-|  |      \-|
#         |  |        |   /-GCF_016699485.2_bGalGal1.mat.broiler.GRCg7b
#         |  |         \-|
#         |  |            \-GCF_016700215.1_bGalGal1.pat.whiteleghornlayer.GRCg7w
#         |  |
#         |  |      /-GCA_009769525.1_bPteGut1.pri
#         |  |   /-|
#         |  |  |   \-GCA_901699155.2_bStrTur1.1
#         |  |  |
#         |  |  |   /-GCA_017976375.1_bCucCan1.pri
#         |  |  |--|
#          \-|  |   \-GCA_009769465.1_bTauEry1.pri
#            |  |
#            |  |   /-GCA_907165065.1_bCapEur3.1
#            |  |--|
#            |  |  |   /-GCA_013368605.1_bNycGra1.pri
#            |  |   \-|
#            |  |     |   /-GCF_003957555.1_bCalAnn1_v1.p
#            |  |      \-|
#            |  |        |   /-GCA_020740795.1_bApuApu2.pri.cur
#            |  |         \-|
#            |  |            \-GCA_020745705.1_bHemCom1.pri.cur
#            |  |
#            |  |--GCA_009819775.1_bPhoRub2.pri
#            |  |
#            |  |      /-GCA_011004875.1_bBalReg1.pri
#            |  |   /-|
#             \-|  |   \-GCA_020800305.1_bPorHoc1.mat.Z.cur
#               |--|
#               |  |   /-GCA_017639485.1_bPluApr1.pri
#               |   \-|
#               |     |   /-GCA_008658365.1_bAlcTor1_primary
#               |      \-|
#               |         \-GCA_009819605.1_bSteHir1.pri
#               |
#               |   /-GCA_017639555.1_bCicMag1.pri
#               |--|
#               |   \-GCA_020745775.1_bTheCae1.pri.cur
#               |
#               |         /-GCF_900496995.4_bAquChr1.4
#               |      /-|
#               |     |   \-GCA_018139145.1_ASM1813914v1
#               |   /-|
#               |  |  |   /-GCA_020746105.1_bTroSur1.pri.cur
#               |  |   \-|
#               |  |     |   /-GCA_009769605.1_bBucAby1.pri
#               |  |      \-|
#               |  |        |   /-GCA_009819595.1_bMerNub1.pri
#               |  |         \-|
#                \-|           |   /-GCA_014839835.1_bDryPub1.pri
#                  |            \-|
#                  |               \-GCA_015220805.1_bPogPus1.pri
#                  |
#                  |   /-GCA_009819825.1_bCarCri1.pri
#                  |  |
#                  |  |      /-GCF_017639655.2_bFalNau1.pat
#                   \-|   /-|
#                     |  |   \-GCF_015220075.1_bFalRus1.pri
#                     |  |
#                     |  |      /-GCF_004027225.2_bStrHab1.2.pri
#                      \-|   /-|
#                        |  |  |   /-GCF_012275295.1_bMelUnd1.mat.Z
#                        |  |   \-|
#                        |  |      \-GCA_017639245.1_MMon_1.0
#                         \-|
#                           |   /-GCA_016904835.1_bAcaChl1.pri
#                           |  |
#                           |  |   /-GCF_009829145.1_bChiLan1.pri
#                            \-|  |
#                              |  |      /-GCA_013407035.1_ASM1340703v1
#                              |  |   /-|
#                               \-|  |  |   /-GCA_020740725.1_bCorHaw1.pri.cur
#                                 |  |   \-|
#                                 |  |     |   /-GCF_000738735.5_ASM73873v5
#                                 |  |      \-|
#                                 |  |         \-GCF_009650955.1_bCorMon1.pri
#                                  \-|
#                                    |      /-GCF_015227805.1_bHirRus1.pri.v2
#                                    |   /-|
#                                    |  |  |   /-GCA_009819655.1_bSylAtr1.pri
#                                    |  |   \-|
#                                    |  |      \-GCA_014839755.1_bSylBor1.pri
#                                     \-|
#                                       |      /-GCF_009819885.2_bCatUst1.pri.v2
#                                       |   /-|
#                                       |  |   \-GCA_903797595.2_bEriRub2.2
#                                        \-|
#                                          |   /-GCF_003957565.2_bTaeGut1.4.pri
#                                          |  |
#                                           \-|   /-GCF_015832195.1_Motacilla_alba_V1.0_pri
#                                             |  |
#                                              \-|      /-GCA_902806625.1_Camarhynchus_parvulus_V1.1
#                                                |   /-|
#                                                |  |   \-GCA_019023105.1_LSU_DiBr_2.0
#                                                 \-|
#                                                   |   /-GCA_009764595.1_bGeoTri1.pri
#                                                    \-|
#                                                       \-GCF_012460135.1_BPBGC_Mater_1.0

# %%
import pandas as pd

sp_table = pd.read_csv(f"{PATH}/Inno_and_genome.tsv", sep = "\t")
sp_table.head()
# Out:
#    Unnamed: 0                              cactus short_ID    VGL ID  \
# 0           0    GCA_008658365.1_bAlcTor1_primary   AlcTor  bAlcTor1
# 1           1          GCA_907165065.1_bCapEur3.1   CapEur  bCapEur3
# 2           2        GCA_009819825.1_bCarCri1.pri   CarCri  bCarCri1
# 3           3        GCA_017639555.1_bCicMag1.pri   CicMag  bCicMag1
# 4           4  GCA_020800305.1_bPorHoc1.mat.Z.cur   PorHoc  bPorHoc1
#
#                   SPECIES               SPECIES.1          COMMON_NAME  \
# 0              Alca torda              Alca_torda            razorbill
# 1   Caprimulgus europaeus   Caprimulgus_europaeus    Eurasian_nightjar
# 2        Cariama cristata        Cariama_cristata   Red-legged_seriema
# 3         Ciconia maguari         Ciconia_maguari        maguari_stork
# 4  Porphyrio hochstetteri  Porphyrio_hochstetteri  South_Island_takahe
#
#           FAMILY             ORDER Songbird  ...  TotInno_resResEff2022 RANK  \
# 0        Alcidae   Charadriiformes        0  ...              -0.869959    1
# 1  Caprimulgidae  Caprimulgiformes        0  ...              -0.823039    2
# 2     Cariamidae     Cariamiformes        0  ...              -0.443525    3
# 3     Ciconiidae     Ciconiiformes        0  ...              -0.436442    4
# 4       Rallidae        Gruiformes        0  ...              -0.412970    5
#
#    TotInno_over0.5_BIN  TotInno_resResEff  FoodInno_resResEff  \
# 0                  0.0          -0.830385           -0.571064
# 1                  0.0          -0.782916           -0.538308
# 2                  0.0          -0.398963           -0.273359
# 3                  0.0          -0.391797           -0.268414
# 4                  0.0          -0.368051           -0.252028
#
#    TechInno_resResEff  Raw_TotInno2022  Relative_Brain_size  BodyMass  \
# 0           -0.468637              0.0            -0.058385    725.99
# 1           -0.441167              0.0            -0.529896     67.00
# 2           -0.218976              0.0             0.294615   1400.00
# 3           -0.214829              0.0             0.247232   3994.99
# 4           -0.201087              0.0            -0.309640   2462.18
#
#                    type
# 0  Non-innovative group
# 1                 Other
# 2                 Other
# 3                 Other
# 4                 Other
#
# [5 rows x 22 columns]

# %%
sp_table

# %%
sp_table["cactus"]
# Out:
# 0                      GCA_008658365.1_bAlcTor1_primary
# 1                            GCA_907165065.1_bCapEur3.1
# 2                          GCA_009819825.1_bCarCri1.pri
# 3                          GCA_017639555.1_bCicMag1.pri
# 4                    GCA_020800305.1_bPorHoc1.mat.Z.cur
# 5                          GCA_009769605.1_bBucAby1.pri
# 6                          GCF_009829145.1_bChiLan1.pri
# 7                        GCF_003957565.2_bTaeGut1.4.pri
# 8                          GCA_013368605.1_bNycGra1.pri
# 9                          GCA_009769525.1_bPteGut1.pri
# 10                         GCA_017976375.1_bCucCan1.pri
# 11                         GCF_009819795.1_bAytFul2.pri
# 12                         GCA_009819775.1_bPhoRub2.pri
# 13                         GCA_015220805.1_bPogPus1.pri
# 14                         GCF_017639655.2_bFalNau1.pat
# 15                         GCA_017639485.1_bPluApr1.pri
# 16                         GCA_014839755.1_bSylBor1.pri
# 17                     GCA_020745705.1_bHemCom1.pri.cur
# 18                           GCA_901699155.2_bStrTur1.1
# 19                        GCF_003957555.1_bCalAnn1_v1.p
# 20                     GCA_020745775.1_bTheCae1.pri.cur
# 21                         GCA_009819595.1_bMerNub1.pri
# 22                         GCA_011004875.1_bBalReg1.pri
# 23                     GCA_020740795.1_bApuApu2.pri.cur
# 24    GCF_016700215.1_bGalGal1.pat.whiteleghornlayer...
# 25          GCF_016699485.2_bGalGal1.mat.broiler.GRCg7b
# 26                         GCF_015220075.1_bFalRus1.pri
# 27                         GCA_016904835.1_bAcaChl1.pri
# 28                      GCF_009769625.2_bCygOlo1.pri.v2
# 29                     GCA_020746105.1_bTroSur1.pri.cur
# 30                      GCF_009819885.2_bCatUst1.pri.v2
# 31                         GCA_009764595.1_bGeoTri1.pri
# 32                         GCA_009819655.1_bSylAtr1.pri
# 33                         GCA_009819605.1_bSteHir1.pri
# 34                           GCA_903797595.2_bEriRub2.2
# 35                         GCF_009650955.1_bCorMon1.pri
# 36                           GCF_900496995.4_bAquChr1.4
# 37                      GCF_015227805.1_bHirRus1.pri.v2
# Name: cactus, dtype: object

# %%
tree.prune(sp_table["SPECIES.1"].tolist())

# %%
for node in tree:
    node.name = node.name
# Out:
# --Sterna_hirundo
#
# --Alca_torda
#
# --Pluvialis_apricaria
#
# --Phoenicopterus_ruber
#
# --Theristicus_caerulescens
#
# --Ciconia_maguari
#
# --Chiroxiphia_lanceolata
#
# --Geothlypis_trichas
#
# --Taeniopygia_guttata
#
# --Erithacus_rubecula
#
# --Catharus_ustulatus
#
# --Sylvia_atricapilla
#
# --Sylvia_borin
#
# --Hirundo_rustica
#
# --Corvus_moneduloides
#
# --Acanthisitta_chloris
#
# --Falco_rusticolus
#
# --Falco_naumanni
#
# --Cariama_cristata
#
# --Pogoniulus_pusillus
#
# --Merops_nubicus
#
# --Bucorvus_abyssinicus
#
# --Trogon_surrucura
#
# --Aquila_chrysaetos
#
# --Porphyrio_hochstetteri
#
# --Balearica_regulorum
#
# --Streptopelia_turtur
#
# --Pterocles_gutturalis
#
# --Cuculus_canorus
#
# --Apus_apus
#
# --Hemiprocne_comata
#
# --Calypte_anna
#
# --Nyctibius_grandis
#
# --Caprimulgus_europaeus
#
# --Gallus_gallus
#
# --Aythya_fuligula
#
# --Cygnus_olor

# %%
dir(node)
# Out:
# ['__add__',
#  '__and__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_asciiArt',
#  '_children',
#  '_diff',
#  '_dist',
#  '_get_children',
#  '_get_dist',
#  '_get_face_areas',
#  '_get_farthest_and_closest_leaves',
#  '_get_style',
#  '_get_support',
#  '_get_up',
#  '_img_style',
#  '_iter_descendants_levelorder',
#  '_iter_descendants_postorder',
#  '_iter_descendants_preorder',
#  '_set_children',
#  '_set_dist',
#  '_set_face_areas',
#  '_set_style',
#  '_set_support',
#  '_set_up',
#  '_support',
#  '_up',
#  'add_child',
#  'add_face',
#  'add_feature',
#  'add_features',
#  'add_sister',
#  'check_monophyly',
#  'children',
#  'compare',
#  'convert_to_ultrametric',
#  'cophenetic_matrix',
#  'copy',
#  'del_feature',
#  'delete',
#  'describe',
#  'detach',
#  'dist',
#  'expand_polytomies',
#  'faces',
#  'features',
#  'from_parent_child_table',
#  'from_skbio',
#  'get_ancestors',
#  'get_ascii',
#  'get_cached_content',
#  'get_children',
#  'get_closest_leaf',
#  'get_common_ancestor',
#  'get_descendants',
#  'get_distance',
#  'get_edges',
#  'get_farthest_leaf',
#  'get_farthest_node',
#  'get_leaf_names',
#  'get_leaves',
#  'get_leaves_by_name',
#  'get_midpoint_outgroup',
#  'get_monophyletic',
#  'get_sisters',
#  'get_topology_id',
#  'get_tree_root',
#  'img_style',
#  'is_leaf',
#  'is_root',
#  'iter_ancestors',
#  'iter_descendants',
#  'iter_edges',
#  'iter_leaf_names',
#  'iter_leaves',
#  'iter_prepostorder',
#  'iter_search_nodes',
#  'ladderize',
#  'name',
#  'phonehome',
#  'populate',
#  'prune',
#  'remove_child',
#  'remove_sister',
#  'render',
#  'resolve_polytomy',
#  'robinson_foulds',
#  'search_nodes',
#  'set_outgroup',
#  'set_style',
#  'show',
#  'sort_descendants',
#  'standardize',
#  'support',
#  'swap_children',
#  'traverse',
#  'unroot',
#  'up',
#  'write']

# %%
node.name
# Out:
# 'Cygnus_olor'
